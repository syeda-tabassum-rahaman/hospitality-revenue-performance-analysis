# %%
import pandas as pd

df_bookings = pd.read_csv("../data/raw/fact_bookings.csv")
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
df_date = pd.read_csv("../data/raw/dim_date.csv")
df_hotels = pd.read_csv("../data/raw/dim_hotels.csv")
df_rooms = pd.read_csv("../data/raw/dim_rooms.csv")
df_agg_bookings = pd.read_csv("../data/raw/fact_aggregated_bookings.csv")

# %%
df_bookings.shape
# Out:
# (134573, 12)

# %%
df_bookings.room_category.unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
df_bookings.booking_platform.value_counts()
# Out:
# booking_platform
# others            55061
# makeyourtrip      26896
# logtrip           14753
# direct online     13374
# tripster           9630
# journey            8106
# direct offline     6753
# Name: count, dtype: int64

# %%
df_bookings.booking_platform.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='booking_platform'>

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134573.000000  134573.000000   56676.000000      134573.000000
# mean    18061.191658       2.036716       3.619045       14915.959776
# std      1093.042273       1.031673       1.234983        6452.676164
# min     16558.000000       1.000000       1.000000        6500.000000
# 25%     17558.000000       1.000000       3.000000        9900.000000
# 50%     17564.000000       2.000000       4.000000       13500.000000
# 75%     18563.000000       2.000000       5.000000       18000.000000
# max     19563.000000       6.000000       5.000000       45220.000000
#
#        revenue_realized
# count     134573.000000
# mean       12695.983585
# std         6927.791692
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %% [markdown]
# Data Cleaning

# %%
df_bookings[df_bookings.no_guests <= 0]
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized]
# Index: []

# %%
df_bookings = df_bookings[df_bookings.no_guests > 0]
df_bookings.shape
# Out:
# (134573, 12)

# %%
mean = df_bookings['revenue_generated'].mean()
std = df_bookings['revenue_generated'].std()
print (f"Mean: {mean}, Std Dev: {std}")
# Out:
# Mean: 14915.959776478194, Std Dev: 6452.676164334521

# %%
Higher_limit = mean + 3*std

# %%
df_bookings[df_bookings.revenue_generated > Higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 137      May012216559RT41        16559     27-04-22      1/5/2022
# 139      May012216559RT43        16559     1/5/2022      1/5/2022
# 143      May012216559RT47        16559     28-04-22      1/5/2022
# 149     May012216559RT413        16559     24-04-22      1/5/2022
# 153     May012216559RT417        16559     30-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134331  Jul312219560RT412        19560     31-07-22      31-07-22
# 134467   Jul312219562RT45        19562     28-07-22      31-07-22
# 134469   Jul312219562RT47        19562    10/7/2022      31-07-22
# 134474  Jul312219562RT412        19562     25-07-22      31-07-22
# 134581   Jul312217564RT42        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 137         7/5/2022        4.0           RT4           others            NaN
# ...

# %%
df_bookings = df_bookings[df_bookings.revenue_generated < Higher_limit]
df_bookings.shape
# Out:
# (133054, 12)

# %%
df_bookings.revenue_realized.describe()
# Out:
# count    133054.000000
# mean      12468.802749
# std        6537.725429
# min        2600.000000
# 25%        7600.000000
# 50%       11400.000000
# 75%       15300.000000
# max       34200.000000
# Name: revenue_realized, dtype: float64

# %% [markdown]
# Data Transformation

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
df_agg_bookings["occ_pct"] = (df_agg_bookings["successful_bookings"] / df_agg_bookings["capacity"]* 100).round(2)
df_agg_bookings.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
#
#    occ_pct
# 0    83.33
# 1    93.33
# 2    76.67
# 3   157.89

# %% [markdown]
# **What is an average occupancy rate in each of the room categories**

# %%
df_agg_bookings.groupby("room_category")["occ_pct"].mean().round(2)
# Out:
# room_category
# RT1    58.22
# RT2    58.04
# RT3    58.03
# RT4    59.30
# Name: occ_pct, dtype: float64

# %%
df_rooms.head()
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df = pd.merge(df_agg_bookings, df_rooms, left_on="room_category", right_on="room_id")
df.tail(4)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
#       occ_pct room_id    room_class
# 9196    72.22     RT4  Presidential
# 9197    50.00     RT4  Presidential
# 9198    50.00     RT4  Presidential
# 9199    75.00     RT4  Presidential

# %%
df.groupby("room_class")["occ_pct"].mean().round(2)
# Out:
# room_class
# Elite           58.04
# Premium         58.03
# Presidential    59.30
# Standard        58.22
# Name: occ_pct, dtype: float64

# %%
df.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
#
#    occ_pct room_class
# 0    83.33   Standard
# 1    93.33   Standard
# 2    76.67   Standard
# 3   157.89   Standard

# %% [markdown]
# **Print average occupancy rate per city**

# %%
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df = pd.merge(df, df_hotels, on="property_id")
df.tail(4)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
#       occ_pct    room_class  property_name  category       city
# 9196    72.22  Presidential  Atliq Exotica    Luxury     Mumbai
# 9197    50.00  Presidential   Atliq Grands    Luxury     Mumbai
# 9198    50.00  Presidential   Atliq Palace  Business  Bangalore
# 9199    75.00  Presidential      Atliq Blu    Luxury     Mumbai

# %%
df.groupby("city")["occ_pct"].mean().round(2).plot(kind='bar')
# Out:
# <Axes: xlabel='city'>

# %% [markdown]
# **when was the occupancy better?Weekday or Weekend**

# %%
df_date.head()
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday
# 4  05-May-22  May 22    W 19  weekeday

# %%
df = pd.merge(df, df_date, left_on="check_in_date", right_on="date")
df.tail(4)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 6496        16559     31-Jul-22           RT4                   13      18.0
# 6497        17558     31-Jul-22           RT4                    3       6.0
# 6498        19563     31-Jul-22           RT4                    3       6.0
# 6499        17561     31-Jul-22           RT4                    3       4.0
#
#       occ_pct    room_class  property_name  category       city       date  \
# 6496    72.22  Presidential  Atliq Exotica    Luxury     Mumbai  31-Jul-22
# 6497    50.00  Presidential   Atliq Grands    Luxury     Mumbai  31-Jul-22
# 6498    50.00  Presidential   Atliq Palace  Business  Bangalore  31-Jul-22
# 6499    75.00  Presidential      Atliq Blu    Luxury     Mumbai  31-Jul-22
#
#       mmm yy week no day_type
# 6496  Jul 22    W 32  weekend
# 6497  Jul 22    W 32  weekend
# 6498  Jul 22    W 32  weekend
# 6499  Jul 22    W 32  weekend

# %%
df.groupby("day_type")["occ_pct"].mean().round(2)
# Out:
# day_type
# weekeday    50.90
# weekend     72.39
# Name: occ_pct, dtype: float64

# %% [markdown]
# **In the month of june, what is the occupancy for different cities**

# %%
df[df["mmm yy"] == "Jun 22"].groupby("city")["occ_pct"].mean().round(2)
# Out:
# city
# Bangalore    56.58
# Delhi        62.47
# Hyderabad    58.46
# Mumbai       58.38
# Name: occ_pct, dtype: float64

# %%
df_august = pd.read_csv("../data/raw/new_data_august.csv")

# %%
df_august.shape
# Out:
# (7, 13)

# %%
latest_df = pd.concat([df, df_august], ignore_index=True, axis=0)
latest_df.tail(4)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 6503        19558     01-Aug-22           RT1                   30      40.0
# 6504        19560     01-Aug-22           RT1                   20      26.0
# 6505        17561     01-Aug-22           RT1                   18      26.0
# 6506        17564     01-Aug-22           RT1                   10      16.0
#
#       occ_pct room_class  property_name  category       city date  mmm yy  \
# 6503      NaN   Standard   Atliq Grands    Luxury  Bangalore  NaN  Aug-22
# 6504      NaN   Standard     Atliq City  Business  Bangalore  NaN  Aug-22
# 6505      NaN   Standard      Atliq Blu    Luxury     Mumbai  NaN  Aug-22
# 6506      NaN   Standard  Atliq Seasons  Business     Mumbai  NaN  Aug-22
#
#      week no  day_type   occ%
# 6503    W 32  weekeday  75.00
# 6504    W 32  weekeday  76.92
# 6505    W 32  weekeday  69.23
# 6506    W 32  weekeday  62.50

# %%
latest_df.shape
# Out:
# (6507, 15)

# %%
df_bookings_all = pd.merge(df_bookings, df_hotels, on = "property_id")
df_bookings_all.tail(4)
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 133050   Jul312217564RT46        17564     29-07-22      31-07-22
# 133051   Jul312217564RT48        17564     30-07-22      31-07-22
# 133052   Jul312217564RT49        17564     29-07-22      31-07-22
# 133053  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 133050      3/8/2022        1.0           RT4     makeyourtrip            2.0
# 133051      2/8/2022        1.0           RT4         tripster            NaN
# 133052      1/8/2022        2.0           RT4          logtrip            2.0
# 133053      1/8/2022        2.0           RT4     makeyourtrip            NaN
#
#        booking_status  revenue_generated  revenue_realized  property_name  \
# 133050    Checked Out              32300             32300  Atliq Seasons
# 133051      Cancelled              32300             12920  Atliq Seasons
# ...

# %%
df_bookings_all.groupby("city")["revenue_realized"].sum()
# Out:
# city
# Bangalore    415109340
# Delhi        289377088
# Hyderabad    325179310
# Mumbai       629358343
# Name: revenue_realized, dtype: int64

# %%
df_date["mmm yy"].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
df_date["date"] = pd.to_datetime(df_date["date"])

# %%
df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     datetime64[ns]
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 3.0+ KB

# %%
df_bookings = pd.read_csv("../data/raw/fact_bookings.csv")
df_hotels = pd.read_csv("../data/raw/dim_hotels.csv")

# %%
df_bookings_all = pd.merge(
    df_bookings,
    df_hotels,
    on="property_id",
    how="left"
)
df_bookings_all.tail(4)
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 134586      1/8/2022       -4.0           RT4          logtrip            2.0
# 134587      2/8/2022        1.0           RT4         tripster            NaN
# 134588      1/8/2022        2.0           RT4          logtrip            2.0
# 134589      1/8/2022        2.0           RT4     makeyourtrip            NaN
#
#        booking_status  revenue_generated  revenue_realized  property_name  \
# 134586    Checked Out              38760             38760  Atliq Seasons
# 134587      Cancelled              32300             12920  Atliq Seasons
# ...

# %%
df_bookings_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134590 entries, 0 to 134589
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134590 non-null  object
#  1   property_id        134590 non-null  int64
#  2   booking_date       134590 non-null  object
#  3   check_in_date      134590 non-null  object
#  4   checkout_date      134590 non-null  object
#  5   no_guests          134587 non-null  float64
#  6   room_category      134590 non-null  object
#  7   booking_platform   134590 non-null  object
#  8   ratings_given      56683 non-null   float64
#  9   booking_status     134590 non-null  object
#  10  revenue_generated  134590 non-null  int64
#  11  revenue_realized   134590 non-null  int64
#  12  property_name      134590 non-null  object
#  13  category           134590 non-null  object
#  14  city               134590 non-null  object
# ...

# %%
df_bookings_all["check_in_date"] = pd.to_datetime(
    df_bookings_all["check_in_date"],format="mixed"
)

# %%
df_bookings_all.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22    2022-01-05      2/5/2022
# 1  May012216558RT12        16558     30-04-22    2022-01-05      2/5/2022
# 2  May012216558RT13        16558     28-04-22    2022-01-05      4/5/2022
# 3  May012216558RT14        16558     28-04-22    2022-01-05      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized property_name category   city
# 0              10010             10010  Atliq Grands   Luxury  Delhi
# 1               9100              3640  Atliq Grands   Luxury  Delhi
# ...

# %%
df_date.head()
# Out:
#         date  mmm yy week no  day_type
# 0 2022-05-01  May 22    W 19   weekend
# 1 2022-05-02  May 22    W 19  weekeday
# 2 2022-05-03  May 22    W 19  weekeday
# 3 2022-05-04  May 22    W 19  weekeday
# 4 2022-05-05  May 22    W 19  weekeday

# %%
df_all_bookings_new = pd.merge(df_bookings_all, df_date, left_on="check_in_date", right_on="date")
df_all_bookings_new.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May052216558RT11        16558     15-04-22    2022-05-05      7/5/2022
# 1  May052216558RT12        16558     30-04-22    2022-05-05      7/5/2022
# 2  May052216558RT13        16558     1/5/2022    2022-05-05      6/5/2022
# 3  May052216558RT14        16558     3/5/2022    2022-05-05      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        3.0           RT1         tripster            5.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        3.0           RT1   direct offline            5.0    Checked Out
# 3        2.0           RT1         tripster            3.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city  \
# 0              10010             10010  Atliq Grands   Luxury  Delhi
# 1               9100              3640  Atliq Grands   Luxury  Delhi
# ...

# %%
df_all_bookings_new.groupby("mmm yy")["revenue_realized"].sum()
# Out:
# mmm yy
# Jul 22    390005772
# Jun 22    377191229
# May 22    408375641
# Name: revenue_realized, dtype: int64

# %% [markdown]
# **Print Revenue realized per hotel type**

# %%
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df_all_bookings_new.groupby("category")["revenue_realized"].sum().sort_values(ascending=False)
# Out:
# category
# Luxury      723569667
# Business    452002975
# Name: revenue_realized, dtype: int64

# %% [markdown]
# **Print average rating per city**

# %%
df_all_bookings_new.groupby('city')["ratings_given"].mean().sort_values(ascending=False)
# Out:
# city
# Delhi        3.774979
# Hyderabad    3.664286
# Mumbai       3.644219
# Bangalore    3.403911
# Name: ratings_given, dtype: float64

# %% [markdown]
# **Print a pie chart of revenue realized per booking platform**

# %%
revenue_by_platform = (
    df_bookings_all
    .groupby("booking_platform")["revenue_realized"]
    .sum()
)

# %%
revenue_by_platform.plot(
    kind="pie",
    autopct="%1.1f%%",
    figsize=(6, 6)
)
# Out:
# <Axes: ylabel='revenue_realized'>
